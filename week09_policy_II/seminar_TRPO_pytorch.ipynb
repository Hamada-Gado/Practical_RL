# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash

    # !pip install -q gymnasium

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
from typing import Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import gymnasium as gym

env = gym.make("Acrobot-v1", render_mode="rgb_array")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# Action Space Discrete(3)

# %%
plt.imshow(env.render())

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $\pi_\theta \left( a \middle| s \right)$.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape: Tuple[int], n_actions: int):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple:
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        super().__init__()

        assert isinstance(state_shape, tuple)
        assert len(state_shape) == 1
        input_dim = state_shape[0]
        
        # Prepare your model here.
        self.model = nn.Sequential(
            nn.Linear(input_dim, 100),
            nn.ReLU(),
            nn.Linear(100, 500),
            nn.ReLU(),
            nn.Linear(500, n_actions) 
        )
        
    def forward(self, states: torch.Tensor):
        """
        takes agent's observation, returns log-probabilities
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for the given states.
        out = self.model(states)
        log_probs = F.log_softmax(out, dim=1)
        
        return log_probs

    def get_log_probs(self, states: torch.Tensor):
        '''
        Log-probs for training
        '''
        return self.forward(states)

    def get_probs(self, states: torch.Tensor):
        '''
        Probs for interaction
        '''
        return torch.exp(self.forward(states))

    def act(self, obs: np.ndarray, sample: bool = True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        with torch.no_grad():
            probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(torch.tensor(env.reset()[0][np.newaxis], dtype=torch.float32))
assert (
    isinstance(log_probs, torch.Tensor) and
    log_probs.requires_grad
), "log_probs must be a torch.Tensor with grad"
assert log_probs.shape == (1, n_actions)
sums = torch.exp(log_probs).sum(dim=1)
assert torch.allclose(sums, torch.ones_like(sums))

# Demo use
print("sampled:", [agent.act(env.reset()[0]) for _ in range(5)])
print("greedy:", [agent.act(env.reset()[0], sample=False) for _ in range(5)])
# Out:
# sampled: [(1, array([0.38015574, 0.3326326 , 0.2872117 ], dtype=float32)), (1, array([0.38061237, 0.33333826, 0.28604934], dtype=float32)), (1, array([0.3825432 , 0.33227625, 0.28518048], dtype=float32)), (0, array([0.37897465, 0.3341408 , 0.28688458], dtype=float32)), (2, array([0.37987903, 0.33300376, 0.28711718], dtype=float32))]
# greedy: [(0, array([0.37925053, 0.3335564 , 0.28719312], dtype=float32)), (0, array([0.37790507, 0.33436334, 0.28773165], dtype=float32)), (0, array([0.3800923 , 0.33362746, 0.2862802 ], dtype=float32)), (0, array([0.37872845, 0.33374998, 0.28752154], dtype=float32)), (0, array([0.38117352, 0.3328464 , 0.2859801 ], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = [torch.ravel(param.detach()) for param in model.parameters()]
    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.shape)))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].reshape(param.shape)
        )
        prev_ind += flat_size

# %% [markdown]
# Compute cumulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cumulative_returns(r, gamma=1):
    """
    Computes cumulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cumulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: agent - has act function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation, _ = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, terminated, truncated, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if terminated or truncated or total_timesteps >= n_timesteps:
                path = {
                    "observations": np.array(obervations),
                    "policy": np.array(action_probs),
                    "actions": np.array(actions),
                    "rewards": np.array(rewards),
                    "cumulative_returns": get_cumulative_returns(rewards),
                }
                paths.append(path)
                break
    return paths

# %%
from pprint import pprint

paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
pprint(paths[-1])

assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,) + observation_shape)
assert (paths[0]['actions'].shape == (5,))

print("It's ok")
# Out:
# {'actions': array([0, 1, 1, 2, 0]),
#  'cumulative_returns': array([-5., -4., -3., -2., -1.]),
#  'observations': array([[ 0.9960101 ,  0.08924031,  0.99798834, -0.06339768, -0.02145215,
#         -0.04616805],
#        [ 0.9962669 ,  0.08632628,  0.9957692 , -0.09188956, -0.00820161,
#         -0.23492911],
#        [ 0.99738175,  0.07231655,  0.99280715, -0.11972473, -0.13017389,
#         -0.04264927],
#        [ 0.9993382 ,  0.03637547,  0.99394834, -0.10984869, -0.22206195,
#          0.13465649],
#        [ 0.9996698 , -0.02569653,  0.99933267, -0.03652743, -0.38374048,
#          0.57817894]], dtype=float32),
#  'policy': array([[0.3824139 , 0.33281612, 0.28477007],
#        [0.38502494, 0.33209604, 0.282879  ],
#        [0.38220593, 0.33315507, 0.28463903],
#        [0.37985757, 0.3337425 , 0.28639993],
#        [0.37524694, 0.33644098, 0.2883121 ]], dtype=float32),
#  'rewards': array([-1., -1., -1., -1., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be:
# $$J_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, in this assignment we are going to use cumulative rewards instead of advantage:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Since we want to maximize the reward, we are going to minimize the corresponding surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps]
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    probs_all = agent.get_probs(observations)

    probs_for_actions = probs_all[torch.arange(batch_size), actions]
    old_probs_for_actions = old_probs[torch.arange(batch_size), actions]

    # Compute surrogate loss, aka importance-sampled policy gradient
    loss = -torch.mean(probs_for_actions / old_probs_for_actions * cumulative_returns)

    assert loss.ndim == 0
    return loss

# %% [markdown]
# We can ascend these gradients as long as our $\pi_\theta(a|s)$ satisfies the constraint
# $$\mathbb{E}_{s,\pi_{\theta_{t}}} \Big[ \operatorname{KL} \left( \pi_{\theta_{t}} (s) \:\|\: \pi_{\theta_{t+1}} (s) \right) \Big] < \alpha$$
#
#
# where
#
# $$\operatorname{KL} \left( p \| q \right) = \mathbb{E}_p \log \left( \frac p q \right)$$

# %%
def get_kl(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps] (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above).
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took.
    # You will also need to compute max KL over all timesteps.
    old_log_probs = torch.log(old_probs + 1e-10)

    kl = (old_probs * (old_log_probs - log_probs_all)).sum(dim=1).mean()

    assert kl.ndim == 0
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = torch.tensor(observations, dtype=torch.float32)

    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = (-probs_all * log_probs_all).sum(dim=1).mean(dim=0)

    assert entropy.ndim == 0
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x: torch.Tensor, fullstep: torch.Tensor, max_kl: float, max_backtracks: int = 10, backtrack_coef: float = 0.5):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    loss, _, = f(x)
    for stepfrac in backtrack_coef**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        if kl <= max_kl and new_loss < loss:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve $A x = b$ using conjugate gradients.
#
# In general, CG is an algorithm that solves $A x = b$ where $A$ is positive-defined. $A$ is the Hessian matrix so $A$ is positive-defined. You can find out more about CG [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method).

# %%
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using an iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros_like(b)
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = A.T @ A


def f_Ax(x):
    return torch.ravel(torch.tensor(A, dtype=torch.float32) @ x.reshape(-1, 1))


b = np.random.rand(8)
w = (np.linalg.inv(A.T @ A) @ A.T @ b.reshape(-1, 1)).reshape(-1)

print(w)
print(conjugate_gradient(f_Ax, torch.tensor(b, dtype=torch.float32)).numpy())
# Out:
# [ -29.41123225  -12.14300525    2.75579419  282.35108119  170.44339538
#  -186.07226507 -120.26346971  -62.87786146]
# [ -29.400148  -12.176261    2.752883  282.13422   170.31207  -185.9895
#  -120.21268   -62.849792]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cumulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cumulative_returns - batch of cumulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = torch.tensor(observations, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int64)
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)
    old_probs = torch.tensor(old_probs, dtype=torch.float32)

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cumulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([torch.ravel(grad.detach()) for grad in grads])

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions, cumulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.reshape(-1) for grad in grads])

        kl_v = (flat_grad_kl * v).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([torch.ravel(grad) for grad in grads]).detach()

        return flat_grad_grad_kl + v * 0.1

    # Here we solve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [
            get_loss(agent, observations, actions, cumulative_returns, old_probs),
            get_kl(agent, observations, actions, cumulative_returns, old_probs),
        ]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count

# TRPO hyperparameter; controls how big KL divergence may be between the old and the new policy at every step.
max_kl = 0.01
numeptotal = 0  # Number of episodes we have completed so far.

start_time = time.time()

for i in count(1):
    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = {}
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 102
# Average sum of rewards per episode:       -490.1078431372549
# Std of rewards per episode:               51.31886227070616
# Time elapsed:                             0.39 mins
# KL between old and new distribution:      0.009998966
# Entropy:                                  1.0810342
# Surrogate loss:                           247.22168
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 205
# Average sum of rewards per episode:       -485.3009708737864
# Std of rewards per episode:               43.767664384329954
# Time elapsed:                             0.72 mins
# KL between old and new distribution:      0.009996922
# Entropy:                                  1.0739923
# Surrogate loss:                           244.28578
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 312
# Average sum of rewards per episode:       -466.9906542056075
# Std of rewards per episode:               58.845194553182694
# Time elapsed:                             1.07 mins
# KL between old and new distribution:      0.009983788
# Entropy:                                  1.0639011
# Surrogate loss:                           236.66148
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 421
# Average sum of rewards per episode:       -458.35779816513764
# Std of rewards per episode:               75.66458128614055
# Time elapsed:                             1.41 mins
# KL between old and new distribution:      0.009983086
# Entropy:                                  1.0437286
# Surrogate loss:                           234.90964
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 534
# Average sum of rewards per episode:       -441.9734513274336
# Std of rewards per episode:               79.24985248047363
# Time elapsed:                             1.78 mins
# KL between old and new distribution:      0.009988759
# Entropy:                                  1.0342879
# Surrogate loss:                           227.41788
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 687
# Average sum of rewards per episode:       -325.8627450980392
# Std of rewards per episode:               83.61857525940124
# Time elapsed:                             2.17 mins
# KL between old and new distribution:      0.009971447
# Entropy:                                  1.0031936
# Surrogate loss:                           172.88786
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 906
# Average sum of rewards per episode:       -227.31963470319636
# Std of rewards per episode:               63.02212504046033
# Time elapsed:                             2.55 mins
# KL between old and new distribution:      0.009974453
# Entropy:                                  0.9612153
# Surrogate loss:                           121.74306
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 1185
# Average sum of rewards per episode:       -178.21863799283153
# Std of rewards per episode:               40.55845213666318
# Time elapsed:                             2.96 mins
# KL between old and new distribution:      0.009986348
# Entropy:                                  0.90244526
# Surrogate loss:                           93.25576
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 1523
# Average sum of rewards per episode:       -146.93491124260356
# Std of rewards per episode:               34.18590699142618
# Time elapsed:                             3.34 mins
# KL between old and new distribution:      0.00997763
# Entropy:                                  0.839003
# Surrogate loss:                           77.00875
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 1908
# Average sum of rewards per episode:       -128.87792207792208
# Std of rewards per episode:               39.1587930228565
# Time elapsed:                             3.72 mins
# KL between old and new distribution:      0.009989112
# Entropy:                                  0.792878
# Surrogate loss:                           69.96745
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 2313
# Average sum of rewards per episode:       -122.45925925925926
# Std of rewards per episode:               37.08870174301289
# Time elapsed:                             4.13 mins
# KL between old and new distribution:      0.0099808695
# Entropy:                                  0.73345065
# Surrogate loss:                           66.46567
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 2749
# Average sum of rewards per episode:       -113.68119266055047
# Std of rewards per episode:               28.903536408650496
# Time elapsed:                             4.53 mins
# KL between old and new distribution:      0.009987606
# Entropy:                                  0.7124572
# Surrogate loss:                           60.25288
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 3199
# Average sum of rewards per episode:       -110.11333333333333
# Std of rewards per episode:               30.559640050236194
# Time elapsed:                             4.94 mins
# KL between old and new distribution:      0.009994057
# Entropy:                                  0.70351547
# Surrogate loss:                           58.97753
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 3646
# Average sum of rewards per episode:       -110.85906040268456
# Std of rewards per episode:               28.900899903368742
# Time elapsed:                             5.46 mins
# KL between old and new distribution:      0.009988688
# Entropy:                                  0.6957743
# Surrogate loss:                           58.88009
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 4097
# Average sum of rewards per episode:       -109.86917960088692
# Std of rewards per episode:               30.675155218253977
# Time elapsed:                             5.95 mins
# KL between old and new distribution:      0.00998114
# Entropy:                                  0.6606597
# Surrogate loss:                           58.9169
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 4574
# Average sum of rewards per episode:       -103.82389937106919
# Std of rewards per episode:               27.15609075876073
# Time elapsed:                             6.46 mins
# KL between old and new distribution:      0.009997696
# Entropy:                                  0.6314391
# Surrogate loss:                           55.15399
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 5048
# Average sum of rewards per episode:       -104.4873417721519
# Std of rewards per episode:               22.237802993177194
# Time elapsed:                             6.89 mins
# KL between old and new distribution:      0.009996405
# Entropy:                                  0.60975873
# Surrogate loss:                           54.3444
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 5533
# Average sum of rewards per episode:       -102.09484536082475
# Std of rewards per episode:               22.83403306937257
# Time elapsed:                             7.34 mins
# KL between old and new distribution:      0.009994019
# Entropy:                                  0.5826928
# Surrogate loss:                           53.3638
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 6021
# Average sum of rewards per episode:       -101.4610655737705
# Std of rewards per episode:               24.32823952136313
# Time elapsed:                             7.78 mins
# KL between old and new distribution:      0.009979766
# Entropy:                                  0.55075055
# Surrogate loss:                           53.34797
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 6527
# Average sum of rewards per episode:       -97.81620553359684
# Std of rewards per episode:               23.144156721408272
# Time elapsed:                             8.26 mins
# KL between old and new distribution:      0.00998086
# Entropy:                                  0.48369718
# Surrogate loss:                           51.39166
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 7054
# Average sum of rewards per episode:       -93.88045540796963
# Std of rewards per episode:               26.9362684718094
# Time elapsed:                             8.70 mins
# KL between old and new distribution:      0.009981021
# Entropy:                                  0.4636718
# Surrogate loss:                           50.47358
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 7568
# Average sum of rewards per episode:       -96.27821011673151
# Std of rewards per episode:               29.85266075234771
# Time elapsed:                             9.19 mins
# KL between old and new distribution:      0.009986531
# Entropy:                                  0.44005945
# Surrogate loss:                           52.497246
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 8105
# Average sum of rewards per episode:       -92.11173184357541
# Std of rewards per episode:               21.11912193140184
# Time elapsed:                             9.65 mins
# KL between old and new distribution:      0.00999649
# Entropy:                                  0.37182525
# Surrogate loss:                           48.293163
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 8659
# Average sum of rewards per episode:       -89.25451263537906
# Std of rewards per episode:               21.71837772255699
# Time elapsed:                             10.16 mins
# KL between old and new distribution:      0.009993918
# Entropy:                                  0.35528195
# Surrogate loss:                           47.04646
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 9215
# Average sum of rewards per episode:       -88.92985611510791
# Std of rewards per episode:               23.40810381982549
# Time elapsed:                             10.61 mins
# KL between old and new distribution:      0.009990018
# Entropy:                                  0.3514266
# Surrogate loss:                           47.32273
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 9761
# Average sum of rewards per episode:       -90.57875457875458
# Std of rewards per episode:               29.502005691831656
# Time elapsed:                             11.07 mins
# KL between old and new distribution:      0.00999743
# Entropy:                                  0.30636904
# Surrogate loss:                           49.836697
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 10316
# Average sum of rewards per episode:       -89.0936936936937
# Std of rewards per episode:               34.81863247512326
# Time elapsed:                             11.53 mins
# KL between old and new distribution:      0.009983126
# Entropy:                                  0.29571962
# Surrogate loss:                           50.9906
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 10887
# Average sum of rewards per episode:       -86.56742556917688
# Std of rewards per episode:               22.306657300506018
# Time elapsed:                             11.97 mins
# KL between old and new distribution:      0.009988275
# Entropy:                                  0.31139845
# Surrogate loss:                           45.9268
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 11446
# Average sum of rewards per episode:       -88.44722719141323
# Std of rewards per episode:               27.206103742772807
# Time elapsed:                             12.47 mins
# KL between old and new distribution:      0.009991758
# Entropy:                                  0.30462134
# Surrogate loss:                           48.147995
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 12010
# Average sum of rewards per episode:       -87.65425531914893
# Std of rewards per episode:               23.667450034004872
# Time elapsed:                             13.05 mins
# KL between old and new distribution:      0.009970571
# Entropy:                                  0.28834242
# Surrogate loss:                           46.78351
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 12575
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               23.287021947466112
# Time elapsed:                             13.58 mins
# KL between old and new distribution:      0.0099964
# Entropy:                                  0.2481693
# Surrogate loss:                           46.62946
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 13128
# Average sum of rewards per episode:       -89.41772151898734
# Std of rewards per episode:               32.38792070304533
# Time elapsed:                             14.04 mins
# KL between old and new distribution:      0.009989159
# Entropy:                                  0.23302193
# Surrogate loss:                           50.29095
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 13709
# Average sum of rewards per episode:       -85.06024096385542
# Std of rewards per episode:               20.83352965643073
# Time elapsed:                             14.44 mins
# KL between old and new distribution:      0.009994727
# Entropy:                                  0.20452896
# Surrogate loss:                           44.890785
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 14294
# Average sum of rewards per episode:       -84.47179487179487
# Std of rewards per episode:               20.655902267580494
# Time elapsed:                             14.82 mins
# KL between old and new distribution:      0.009976575
# Entropy:                                  0.2136384
# Surrogate loss:                           44.561554
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 14879
# Average sum of rewards per episode:       -84.47179487179487
# Std of rewards per episode:               24.844259672181362
# Time elapsed:                             15.21 mins
# KL between old and new distribution:      0.009999808
# Entropy:                                  0.21815908
# Surrogate loss:                           45.64347
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 15479
# Average sum of rewards per episode:       -82.33333333333333
# Std of rewards per episode:               18.457127500116467
# Time elapsed:                             15.60 mins
# KL between old and new distribution:      0.00997838
# Entropy:                                  0.20457238
# Surrogate loss:                           43.01876
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 16075
# Average sum of rewards per episode:       -82.89429530201342
# Std of rewards per episode:               23.495120891611826
# Time elapsed:                             16.01 mins
# KL between old and new distribution:      0.009977933
# Entropy:                                  0.20133859
# Surrogate loss:                           44.61623
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 16672
# Average sum of rewards per episode:       -82.7537688442211
# Std of rewards per episode:               21.325066604709836
# Time elapsed:                             16.41 mins
# KL between old and new distribution:      0.009984087
# Entropy:                                  0.20478438
# Surrogate loss:                           43.93924
#
# ********** Iteration 39 ************
# Rollout
# Made rollout
# Total number of episodes:                 17264
# Average sum of rewards per episode:       -83.46114864864865
# Std of rewards per episode:               22.561069765214516
# Time elapsed:                             16.81 mins
# KL between old and new distribution:      0.009972229
# Entropy:                                  0.21437898
# Surrogate loss:                           44.56456
#
# ********** Iteration 40 ************
# Rollout
# Made rollout
# Total number of episodes:                 17857
# Average sum of rewards per episode:       -83.31871838111299
# Std of rewards per episode:               18.306679280613785
# Time elapsed:                             17.18 mins
# KL between old and new distribution:      0.009997183
# Entropy:                                  0.24165665
# Surrogate loss:                           43.475197
#
# ********** Iteration 41 ************
# Rollout
# Made rollout
# Total number of episodes:                 18425
# Average sum of rewards per episode:       -87.02992957746478
# Std of rewards per episode:               27.551567885563014
# Time elapsed:                             17.51 mins
# KL between old and new distribution:      0.009988392
# Entropy:                                  0.24376497
# Surrogate loss:                           47.57752
#
# ********** Iteration 42 ************
# Rollout
# Made rollout
# Total number of episodes:                 19005
# Average sum of rewards per episode:       -85.21034482758621
# Std of rewards per episode:               28.424441217054447
# Time elapsed:                             17.83 mins
# KL between old and new distribution:      0.009969464
# Entropy:                                  0.22546294
# Surrogate loss:                           47.0028
#
# ********** Iteration 43 ************
# Rollout
# Made rollout
# Total number of episodes:                 19584
# Average sum of rewards per episode:       -85.35751295336787
# Std of rewards per episode:               21.04805730797536
# Time elapsed:                             18.15 mins
# KL between old and new distribution:      0.009996263
# Entropy:                                  0.19780199
# Surrogate loss:                           45.07488
#
# ********** Iteration 44 ************
# Rollout
# Made rollout
# Total number of episodes:                 20187
# Average sum of rewards per episode:       -81.92039800995025
# Std of rewards per episode:               18.37124885750939
# Time elapsed:                             18.50 mins
# KL between old and new distribution:      0.009988386
# Entropy:                                  0.17804132
# Surrogate loss:                           42.84303
#
# ********** Iteration 45 ************
# Rollout
# Made rollout
# Total number of episodes:                 20792
# Average sum of rewards per episode:       -81.64628099173554
# Std of rewards per episode:               18.99927376307709
# Time elapsed:                             18.86 mins
# KL between old and new distribution:      0.009978707
# Entropy:                                  0.1805873
# Surrogate loss:                           42.82829
#
# ********** Iteration 46 ************
# Rollout
# Made rollout
# Total number of episodes:                 21394
# Average sum of rewards per episode:       -82.05813953488372
# Std of rewards per episode:               19.228170308579703
# Time elapsed:                             19.20 mins
# KL between old and new distribution:      0.009990775
# Entropy:                                  0.17094594
# Surrogate loss:                           43.138546
#
# ********** Iteration 47 ************
# Rollout
# Made rollout
# Total number of episodes:                 22003
# Average sum of rewards per episode:       -81.10344827586206
# Std of rewards per episode:               22.695256868621478
# Time elapsed:                             19.58 mins
# KL between old and new distribution:      0.009988045
# Entropy:                                  0.16032375
# Surrogate loss:                           43.535564
#
# ********** Iteration 48 ************
# Rollout
# Made rollout
# Total number of episodes:                 22603
# Average sum of rewards per episode:       -82.335
# Std of rewards per episode:               21.954713427113248
# Time elapsed:                             19.95 mins
# KL between old and new distribution:      0.009997787
# Entropy:                                  0.13421434
# Surrogate loss:                           43.906734
#
# ********** Iteration 49 ************
# Rollout
# Made rollout
# Total number of episodes:                 23215
# Average sum of rewards per episode:       -80.70098039215686
# Std of rewards per episode:               18.714411952426016
# Time elapsed:                             20.31 mins
# KL between old and new distribution:      0.009999958
# Entropy:                                  0.13845181
# Surrogate loss:                           42.37122
#
# ********** Iteration 50 ************
# Rollout
# Made rollout
# Total number of episodes:                 23825
# Average sum of rewards per episode:       -80.96885245901639
# Std of rewards per episode:               20.412805696132704
# Time elapsed:                             20.70 mins
# KL between old and new distribution:      0.0099962065
# Entropy:                                  0.1331274
# Surrogate loss:                           42.88985
#
# ********** Iteration 51 ************
# Rollout
# Made rollout
# Total number of episodes:                 24433
# Average sum of rewards per episode:       -81.23848684210526
# Std of rewards per episode:               23.36222277467431
# Time elapsed:                             21.07 mins
# KL between old and new distribution:      0.009981731
# Entropy:                                  0.118573844
# Surrogate loss:                           43.81913
#
# ********** Iteration 52 ************
# Rollout
# Made rollout
# Total number of episodes:                 25038
# Average sum of rewards per episode:       -81.64628099173554
# Std of rewards per episode:               24.90438920896188
# Time elapsed:                             21.43 mins
# KL between old and new distribution:      0.009997362
# Entropy:                                  0.13070068
# Surrogate loss:                           44.44538
#
# ********** Iteration 53 ************
# Rollout
# Made rollout
# Total number of episodes:                 25631
# Average sum of rewards per episode:       -83.32040472175379
# Std of rewards per episode:               26.76967915249009
# Time elapsed:                             21.79 mins
# KL between old and new distribution:      0.009982543
# Entropy:                                  0.14282943
# Surrogate loss:                           45.64369
#
# ********** Iteration 54 ************
# Rollout
# Made rollout
# Total number of episodes:                 26229
# Average sum of rewards per episode:       -82.61371237458194
# Std of rewards per episode:               20.27650697353236
# Time elapsed:                             22.15 mins
# KL between old and new distribution:      0.009979888
# Entropy:                                  0.1364003
# Surrogate loss:                           43.62338
#
# ********** Iteration 55 ************
# Rollout
# Made rollout
# Total number of episodes:                 26851
# Average sum of rewards per episode:       -79.38745980707395
# Std of rewards per episode:               15.78816878588928
# Time elapsed:                             22.56 mins
# KL between old and new distribution:      0.009995553
# Entropy:                                  0.12744194
# Surrogate loss:                           41.11852
#
# ********** Iteration 56 ************
# Rollout
# Made rollout
# Total number of episodes:                 27440
# Average sum of rewards per episode:       -83.89134125636673
# Std of rewards per episode:               23.598690858930304
# Time elapsed:                             22.99 mins
# KL between old and new distribution:      0.009988721
# Entropy:                                  0.10472479
# Surrogate loss:                           45.03249
#
# ********** Iteration 57 ************
# Rollout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 15
#      13 # Generating paths.
#      14 print("Rollout")
# ---> 15 paths = rollout(env, agent)
#      16 print("Made rollout")
#      18 # Updating policy.
#
# Cell In[10], line 20, in rollout(env, agent, max_pathlength, n_timesteps)
#      18 actions.append(action)
#      19 action_probs.append(policy)
# ---> 20 obervation, reward, terminated, truncated, _ = env.step(action)
#      21 rewards.append(reward)
#      22 total_timesteps += 1
#
# File ~/SharedDisk/ai_courses/Practical_RL/env/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/SharedDisk/ai_courses/Practical_RL/env/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/SharedDisk/ai_courses/Practical_RL/env/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/SharedDisk/ai_courses/Practical_RL/env/lib/python3.10/site-packages/gymnasium/envs/classic_control/acrobot.py:216, in AcrobotEnv.step(self, a)
#     212 # Now, augment the state with our force action so it can be passed to
#     213 # _dsdt
#     214 s_augmented = np.append(s, torque)
# --> 216 ns = rk4(self._dsdt, s_augmented, [0, self.dt])
#     218 ns[0] = wrap(ns[0], -pi, pi)
#     219 ns[1] = wrap(ns[1], -pi, pi)
#
# File ~/SharedDisk/ai_courses/Practical_RL/env/lib/python3.10/site-packages/gymnasium/envs/classic_control/acrobot.py:468, in rk4(derivs, y0, t)
#     466     k3 = np.asarray(derivs(y0 + dt2 * k2))
#     467     k4 = np.asarray(derivs(y0 + dt * k3))
# --> 468     yout[i + 1] = y0 + dt / 6.0 * (k1 + 2 * k2 + 2 * k3 + k4)
#     469 # We only care about the final timestep and we cleave off action value which will be zero
#     470 return yout[-1][:4]
#
# KeyboardInterrupt:

# %%
from gymnasium.wrappers import RecordVideo
from IPython.display import HTML
from pathlib import Path

def evaluate(agent, env, n_games=1):
    """Plays an a game from start till done, returns per-game rewards"""

    game_rewards = []
    for _ in range(n_games):
        state, _ = env.reset()
        total_reward = 0
        while True:
            action, _ = agent.act(state, sample=False)
            state, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward
            if terminated or truncated:
                break
        game_rewards.append(total_reward)
    return game_rewards

with RecordVideo(env, video_folder="videos", disable_logger=True) as env_monitor:
    rewards = evaluate(agent, env_monitor, n_games=3)

video_paths = sorted([s for s in Path('videos').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]  # You can also try other indices
data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))
# Out:
# <video width="640" height="480" controls>
#   <source src="videos/rl-video-episode-1.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.cc/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the MCTS seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about TRPO in the [original paper](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cumulative rewards similar to `get_cumulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gymnasium.farama.org/environments/mujoco/#mujoco)
# * [Box2d robot](https://gymnasium.farama.org/environments/box2d/bipedal_walker/)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use a fully factorized gaussian (basically a vector of gaussians).
#
# __Bonus task__: compare the performance of the continuous action space method to action space discretization.
